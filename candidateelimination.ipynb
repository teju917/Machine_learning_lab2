# %% [markdown]
# <a href="https://colab.research.google.com/github/teju917/Machine_learning_lab2/blob/main/candidateelimination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import ListedColormap


df = pd.read_csv("Mall_Customers.csv")

print("Dataset:")
print(df.head())

print("\nColumns:")
print(df.columns.tolist())



df = df.rename(columns={
    'Annual Income (k$)': 'AnnualIncome',
    'Spending Score (1-100)': 'SpendingScore'
})


# ---------------------------------------------------------
# CREATE CATEGORICAL ATTRIBUTES
# ---------------------------------------------------------

# Age categories
def age_category(age):
    if age < 25:
        return 'Young'
    elif age < 40:
        return 'Adult'
    elif age < 60:
        return 'Middle'
    else:
        return 'Senior'


# Annual income categories
def income_category(income):
    if income < 40:
        return 'Low'
    elif income < 70:
        return 'Medium'
    elif income < 100:
        return 'High'
    else:
        return 'VeryHigh'


# Spending score categories
def spending_category(score):
    if score < 40:
        return 'Low'
    elif score < 60:
        return 'Medium'
    else:
        return 'High'


df['AgeCategory'] = df['Age'].apply(age_category)
df['IncomeCategory'] = df['AnnualIncome'].apply(income_category)
df['SpendingCategory'] = df['SpendingScore'].apply(spending_category)



df['HighSpender'] = np.where(
    df['SpendingScore'] >= 60,
    'Yes',
    'No'
)




attributes = [
    'Gender',
    'AgeCategory',
    'IncomeCategory',
    'SpendingCategory'
]


data = df[attributes + ['HighSpender']].values.tolist()


X = [row[:-1] for row in data]
y = [row[-1] for row in data]

n_attributes = len(attributes)


print("\n====================================")
print("PREPARED DATASET")
print("====================================")

print(df[attributes + ['HighSpender']].head(10))

print("\nTarget distribution:")
print(df['HighSpender'].value_counts())




def more_general(h1, h2):
    """
    Return True if h1 is more general than or equal to h2.
    """

    for x, y_ in zip(h1, h2):

        if x == '?':
            continue

        if x == '0':
            return False

        if x != y_ and y_ != '0':
            return False

    return True


def consistent(h, instance):
    """
    Check whether hypothesis h matches instance.
    """

    for hx, ix in zip(h, instance):

        if hx == '?':
            continue

        if hx != ix:
            return False

    return True


def min_generalizations(h, instance):
    """
    Return minimal generalizations of h
    that match the positive instance.
    """

    new_h = list(h)

    for i in range(len(h)):

        if h[i] == '0':
            new_h[i] = instance[i]

        elif h[i] != instance[i]:
            new_h[i] = '?'

    return [tuple(new_h)]


def min_specializations(h, domains, instance):
    """
    Return minimal specializations of h
    that do NOT match the negative instance.
    """

    results = []

    for i in range(len(h)):

        if h[i] == '?':

            for val in domains[i]:

                if val != instance[i]:

                    new_h = list(h)
                    new_h[i] = val

                    results.append(tuple(new_h))

        elif h[i] != '0':

            new_h = list(h)
            new_h[i] = '0'

            results.append(tuple(new_h))

    return results


def remove_more_general(hyps):
    """
    Remove hypotheses that are more general
    than another hypothesis.
    """

    return [
        h for h in hyps
        if not any(
            h != h2 and more_general(h2, h)
            for h2 in hyps
        )
    ]


def remove_less_general(hyps):
    """
    Remove hypotheses that are less general
    than another hypothesis.
    """

    return [
        h for h in hyps
        if not any(
            h != h2 and more_general(h, h2)
            for h2 in hyps
        )
    ]




def candidate_elimination(X, y, attributes):

    domains = [
        sorted(set(row[i] for row in X))
        for i in range(len(attributes))
    ]

    # Most specific hypothesis
    S = [
        tuple(['0'] * n_attributes)
    ]

    # Most general hypothesis
    G = [
        tuple(['?'] * n_attributes)
    ]

    # History for visualization
    history = {

        'S_sizes': [len(S)],

        'G_sizes': [len(G)],

        'S_sets': [list(S)],

        'G_sets': [list(G)],

        'labels': ['Init']
    }


    for idx, (instance, label) in enumerate(zip(X, y)):

        instance = tuple(instance)




        if label == 'Yes':

            G = [
                g for g in G
                if consistent(g, instance)
            ]

            new_S = []

            for s in S:

                if consistent(s, instance):

                    new_S.append(s)

                else:

                    generalizations = min_generalizations(
                        s,
                        instance
                    )

                    for h in generalizations:

                        if any(
                            more_general(g, h)
                            for g in G
                        ):

                            new_S.append(h)


            S = remove_more_general(
                list(set(new_S))
            )



        else:

            S = [
                s for s in S
                if not consistent(s, instance)
            ]

            new_G = []

            for g in G:

                if not consistent(g, instance):

                    new_G.append(g)

                else:

                    specializations = min_specializations(
                        g,
                        domains,
                        instance
                    )

                    for h in specializations:

                        if any(
                            more_general(h, s)
                            for s in S
                        ):

                            new_G.append(h)


            G = remove_less_general(
                list(set(new_G))
            )



        history['S_sizes'].append(len(S))
        history['G_sizes'].append(len(G))

        history['S_sets'].append(list(S))
        history['G_sets'].append(list(G))

        history['labels'].append(
            f'Customer {idx + 1} ({label})'
        )




        print(
            f"\n--- After Customer {idx + 1} "
            f"({instance} -> {label}) ---"
        )

        print("S (specific boundary):")

        for s in S:
            print("  ", s)

        print("G (general boundary):")

        for g in G:
            print("  ", g)


    return S, G, history



S_final, G_final, history = candidate_elimination(
    X,
    y,
    attributes
)




print("\n============================")
print("FINAL SPECIFIC BOUNDARY (S):")
print("============================")

for s in S_final:
    print("  ", s)


print("\n============================")
print("FINAL GENERAL BOUNDARY (G):")
print("============================")

for g in G_final:
    print("  ", g)




COL_TEAL = '#0f4c4c'
COL_MINT = '#4fd1a5'
COL_LIGHT = '#a8e6cf'
COL_ACCENT = '#ff7f50'
COL_BG = '#f4f9f8'


def specificity_score(h):

    """
    Encode hypothesis into numeric values.

    -1 = empty
     0 = specific value
     1 = ?
    """

    return [
        (
            -1 if v == '0'
            else 1 if v == '?'
            else 0
        )
        for v in h
    ]




fig = plt.figure(
    figsize=(16, 11),
    facecolor=COL_BG
)

fig.suptitle(
    'Candidate-Elimination Algorithm — Mall Customer Analysis',
    fontsize=18,
    fontweight='bold',
    color=COL_TEAL,
    y=0.98
)


# ---------------------------------------------------------
# PLOT 1
# Boundary size trend
# ---------------------------------------------------------

ax1 = plt.subplot(2, 2, 1)

steps = range(len(history['S_sizes']))

ax1.plot(
    steps,
    history['S_sizes'],
    marker='o',
    color=COL_MINT,
    linewidth=2.5,
    label='|S| (Specific boundary)',
    markersize=6
)

ax1.plot(
    steps,
    history['G_sizes'],
    marker='s',
    color=COL_ACCENT,
    linewidth=2.5,
    label='|G| (General boundary)',
    markersize=6
)

ax1.set_xticks(steps)


if len(steps) > 20:

    tick_positions = list(range(0, len(steps), 10))

    ax1.set_xticks(tick_positions)

    ax1.set_xticklabels(
        [
            history['labels'][i]
            for i in tick_positions
        ],
        rotation=30,
        ha='right'
    )

else:

    ax1.set_xticklabels(
        history['labels'],
        rotation=30,
        ha='right'
    )


ax1.set_ylabel('Number of hypotheses')

ax1.set_title(
    'Version Space Boundary Size',
    color=COL_TEAL,
    fontweight='bold'
)

ax1.legend()

ax1.grid(alpha=0.3)

ax1.set_facecolor('white')




ax2 = plt.subplot(2, 2, 2)

s_track = []

for s_set in history['S_sets']:

    h = (
        s_set[0]
        if s_set
        else tuple(['0'] * n_attributes)
    )

    s_track.append(
        specificity_score(h)
    )


s_matrix = np.array(s_track)


cmap = ListedColormap([
    '#e07a5f',
    '#f2f2f2',
    COL_MINT
])


im = ax2.imshow(
    s_matrix,
    aspect='auto',
    cmap=cmap,
    vmin=-1,
    vmax=1
)


ax2.set_xticks(
    range(n_attributes)
)

ax2.set_xticklabels(
    attributes,
    rotation=30,
    ha='right'
)


# Only show selected customer labels
if len(history['labels']) > 20:

    tick_positions = list(
        range(0, len(history['labels']), 10)
    )

    ax2.set_yticks(tick_positions)

    ax2.set_yticklabels(
        [
            history['labels'][i]
            for i in tick_positions
        ]
    )

else:

    ax2.set_yticks(
        range(len(history['labels']))
    )

    ax2.set_yticklabels(
        history['labels']
    )


ax2.set_title(
    'S Boundary Evolution',
    color=COL_TEAL,
    fontweight='bold'
)


patches = [

    mpatches.Patch(
        color='#e07a5f',
        label="'0' (empty)"
    ),

    mpatches.Patch(
        color='#f2f2f2',
        label='Specific value'
    ),

    mpatches.Patch(
        color=COL_MINT,
        label="'?' (generalized)"
    )
]


ax2.legend(
    handles=patches,
    loc='upper center',
    bbox_to_anchor=(0.5, -0.25),
    ncol=3,
    fontsize=8
)



ax3 = plt.subplot(2, 2, 3)

ax3.axis('off')

ax3.set_title(
    'Final Version Space Boundaries',
    color=COL_TEAL,
    fontweight='bold',
    pad=20
)


table_data = []

row_colors = []


for s in S_final:

    table_data.append(
        ['S'] + list(s)
    )

    row_colors.append(
        COL_LIGHT
    )


for g in G_final:

    table_data.append(
        ['G'] + list(g)
    )

    row_colors.append(
        '#ffd8c2'
    )


col_labels = [
    'Set'
] + attributes


if table_data:

    tbl = ax3.table(
        cellText=table_data,
        colLabels=col_labels,
        loc='center',
        cellLoc='center',
        bbox=[0, 0, 1, 1]
    )

    tbl.auto_set_font_size(False)

    tbl.set_fontsize(8)


    for i, color in enumerate(row_colors):

        for j in range(len(col_labels)):

            tbl[
                (i + 1, j)
            ].set_facecolor(color)


    for j in range(len(col_labels)):

        tbl[
            (0, j)
        ].set_facecolor(COL_TEAL)

        tbl[
            (0, j)
        ].set_text_props(
            color='white',
            fontweight='bold'
        )




ax4 = plt.subplot(2, 2, 4)


if S_final:

    s_generality = np.mean(
        [
            [
                1 if v == '?' else 0
                for v in s
            ]
            for s in S_final
        ],
        axis=0
    )

else:

    s_generality = np.zeros(
        n_attributes
    )


if G_final:

    g_generality = np.mean(
        [
            [
                1 if v == '?' else 0
                for v in g
            ]
            for g in G_final
        ],
        axis=0
    )

else:

    g_generality = np.zeros(
        n_attributes
    )


x_pos = np.arange(
    n_attributes
)

width = 0.35


ax4.bar(
    x_pos - width / 2,
    s_generality,
    width,
    label='S boundary',
    color=COL_MINT
)


ax4.bar(
    x_pos + width / 2,
    g_generality,
    width,
    label='G boundary',
    color=COL_ACCENT
)


ax4.set_xticks(x_pos)

ax4.set_xticklabels(
    attributes,
    rotation=30,
    ha='right'
)


ax4.set_ylabel(
    "Fraction of hypotheses with '?'"
)


ax4.set_title(
    'Attribute-Level Generalization',
    color=COL_TEAL,
    fontweight='bold'
)


ax4.legend()

ax4.grid(
    alpha=0.3,
    axis='y'
)

ax4.set_ylim(
    0,
    1.1
)

ax4.set_facecolor('white')




plt.tight_layout(
    rect=[0, 0, 1, 0.96]
)

plt.savefig(
    'mall_customer_candidate_elimination.png',
    dpi=150,
    facecolor=COL_BG
)

plt.show()


print(
    "\nSaved visualization to "
    "mall_customer_candidate_elimination.png"
)
# Out:
# Dataset:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
# Columns:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']
#
# ====================================
# PREPARED DATASET
# ====================================
#    Gender AgeCategory IncomeCategory SpendingCategory HighSpender
# 0    Male       Young            Low              Low          No
# 1    Male       Young            Low             High         Yes
# 2  Female       Young            Low              Low          No
# 3  Female       Young            Low             High         Yes
# 4  Female       Adult            Low           Medium          No
# 5  Female       Young            Low             High         Yes
# 6  Female       Adult            Low              Low          No
# 7  Female       Young            Low             High         Yes
# 8    Male      Senior            Low              Low          No
# 9  Female       Adult            Low             High         Yes
#
# Target distribution:
# HighSpender
# No     135
# Yes     65
# Name: count, dtype: int64
#
# --- After Customer 1 (('Male', 'Young', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('0', '0', '0', '0')
# G (general boundary):
#    ('?', '?', 'VeryHigh', '?')
#    ('?', 'Senior', '?', '?')
#    ('?', '?', '?', 'Medium')
#    ('?', '?', 'Medium', '?')
#    ('?', '?', '?', 'High')
#    ('?', '?', 'High', '?')
#    ('Female', '?', '?', '?')
#    ('?', 'Middle', '?', '?')
#    ('?', 'Adult', '?', '?')
#
# --- After Customer 2 (('Male', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('Male', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 3 (('Female', 'Young', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('Male', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 4 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 5 (('Female', 'Adult', 'Low', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 6 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 7 (('Female', 'Adult', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 8 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 9 (('Male', 'Senior', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', 'Young', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 10 (('Female', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 11 (('Male', 'Senior', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 12 (('Female', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 13 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 14 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 15 (('Male', 'Adult', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 16 (('Male', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 17 (('Female', 'Adult', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 18 (('Male', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 19 (('Male', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 20 (('Female', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 21 (('Male', 'Adult', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 22 (('Male', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 23 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 24 (('Male', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 25 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 26 (('Male', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 27 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 28 (('Male', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 29 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 30 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 31 (('Male', 'Senior', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 32 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 33 (('Male', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 34 (('Male', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 35 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 36 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 37 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 38 (('Female', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 39 (('Female', 'Adult', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 40 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 41 (('Female', 'Senior', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 42 (('Male', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 43 (('Male', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 44 (('Female', 'Adult', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 45 (('Female', 'Middle', 'Low', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 46 (('Female', 'Young', 'Low', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 47 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 48 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 49 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 50 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 51 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', 'Low', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 52 (('Male', 'Adult', 'Medium', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 53 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 54 (('Male', 'Middle', 'Medium', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 55 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 56 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 57 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 58 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 59 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 60 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 61 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 62 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 63 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 64 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 65 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 66 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 67 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 68 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 69 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 70 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 71 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 72 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 73 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 74 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 75 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 76 (('Male', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 77 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 78 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 79 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 80 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 81 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 82 (('Male', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 83 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 84 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 85 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 86 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 87 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 88 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 89 (('Female', 'Adult', 'Medium', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 90 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 91 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 92 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 93 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 94 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 95 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 96 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 97 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 98 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 99 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 100 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 101 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 102 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 103 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 104 (('Male', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 105 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 106 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 107 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 108 (('Male', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 109 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 110 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 111 (('Male', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 112 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 113 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 114 (('Male', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 115 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 116 (('Female', 'Young', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 117 (('Female', 'Senior', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 118 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 119 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 120 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 121 (('Male', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 122 (('Female', 'Adult', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 123 (('Female', 'Middle', 'Medium', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 124 (('Male', 'Adult', 'Medium', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 125 (('Female', 'Young', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 126 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 127 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 128 (('Male', 'Middle', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 129 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 130 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 131 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 132 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 133 (('Female', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 134 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 135 (('Male', 'Young', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 136 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 137 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 138 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 139 (('Male', 'Young', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 140 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 141 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 142 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 143 (('Female', 'Adult', 'High', 'Medium') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 144 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 145 (('Male', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 146 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 147 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 148 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 149 (('Female', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 150 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 151 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 152 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 153 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 154 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 155 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 156 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 157 (('Male', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 158 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 159 (('Male', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 160 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 161 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 162 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 163 (('Male', 'Young', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 164 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 165 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 166 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 167 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 168 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 169 (('Female', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 170 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 171 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 172 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 173 (('Male', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 174 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 175 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 176 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 177 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 178 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 179 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 180 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 181 (('Female', 'Adult', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 182 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 183 (('Male', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 184 (('Female', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 185 (('Female', 'Middle', 'High', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 186 (('Male', 'Adult', 'High', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 187 (('Female', 'Middle', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 188 (('Male', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 189 (('Female', 'Middle', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 190 (('Female', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 191 (('Female', 'Adult', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 192 (('Female', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 193 (('Male', 'Adult', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 194 (('Female', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 195 (('Female', 'Middle', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 196 (('Female', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 197 (('Female', 'Middle', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 198 (('Male', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 199 (('Male', 'Adult', 'VeryHigh', 'Low') -> No) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# --- After Customer 200 (('Male', 'Adult', 'VeryHigh', 'High') -> Yes) ---
# S (specific boundary):
#    ('?', '?', '?', 'High')
# G (general boundary):
#    ('?', '?', '?', 'High')
#
# ============================
# FINAL SPECIFIC BOUNDARY (S):
# ============================
#    ('?', '?', '?', 'High')
#
# ============================
# FINAL GENERAL BOUNDARY (G):
# ============================
#    ('?', '?', '?', 'High')
# Saved visualization to mall_customer_candidate_elimination.png
